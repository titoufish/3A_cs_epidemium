# %%
from sklearn.ensemble import RandomForestRegressor
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from categorical_encoder import categorical_encoding
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# # Inputs

# %%
df = pd.read_csv("C:/Users/titou/Desktop/Centrale/Option OSY/Projet/Datasets/ALL_PCA2_50.csv")

# %% [markdown]
# Select one type of cancer

# %%
df = df.loc[df['type'] == "C16"]

# %% [markdown]
# Categorical encoding of the countries

# %%
df = categorical_encoding(df)
# Out:
# Categorical feature area encoded
# Categorical feature type encoded

# %% [markdown]
# Splitting target and features

# %%
Y = df['relative_mortality']
Y = (Y - Y.min())/(Y.max()-Y.min())

X = df.drop(columns = ['relative_mortality','year'])

# %% [markdown]
# # Model

# %% [markdown]
# Parameters to tune : max_feature, n_estimator, min_sample_leaf

# %%
results = []

# %%
for max_feature in range(1,9):
    for n_estimator in range(10,30):
        for min_sample_leaf in range(1,60,10):
            tr = RandomForestRegressor(max_features = max_feature/10, n_estimators = n_estimator, min_samples_leaf = min_sample_leaf)
            scores = cross_val_score(tr, X, Y)
            results += [(max_feature, n_estimator, min_sample_leaf, scores.mean())]
            print('max_feature = ', max_feature/10)
            print('n_estimator = ', n_estimator)
            print('min_sample_leaf = ', min_sample_leaf)
            print('score : ', scores.mean())
# Out:
# max_feature =  0.1
# n_estimator =  10
# min_sample_leaf =  1
# score :  0.8339121771645672
# max_feature =  0.1
# n_estimator =  10
# min_sample_leaf =  11
# score :  0.7777912920674049
# max_feature =  0.1
# n_estimator =  10
# min_sample_leaf =  21
# score :  0.7043032007161537
# max_feature =  0.1
# n_estimator =  10
# min_sample_leaf =  31
# score :  0.643242232421903
# max_feature =  0.1
# n_estimator =  10
# min_sample_leaf =  41
# score :  0.5829265528456832
# max_feature =  0.1
# n_estimator =  10
# min_sample_leaf =  51
# score :  0.5561211532012983
# max_feature =  0.1
# n_estimator =  11
# min_sample_leaf =  1
# score :  0.8408581227422097
# max_feature =  0.1
# n_estimator =  11
# min_sample_leaf =  11
# score :  0.7658106677969077
# max_feature =  0.1
# n_estimator =  11
# min_sample_leaf =  21
# score :  0.6976862739106346
# max_feature =  0.1
# n_estimator =  11
# min_sample_leaf =  31
# score :  0.6364097057138112
# max_feature =  0.1
# n_estimator =  11
# ...

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 20, 30, 50]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4, 5, 10, 15, 20, 30, 50, 70]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
rf = RandomForestRegressor()
# Random search of parameters, using 3 fold cross validation, 
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)

rf_random.fit(X, Y)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed: 15.6min

# %%
rf_random.best_params_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-ea266b0743c6> in <module>()
# ----> 1 rf_random.best_params_
#
# AttributeError: 'RandomizedSearchCV' object has no attribute 'best_params_'
